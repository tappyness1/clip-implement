# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")

import numpy as np
import pandas as pd
import glob
from src.dataset import FlickrDataset
from torchvision.io import read_image
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = FlickrDataset(image_folder_path = "../../data/flickr-dataset/Images/", caption_path = "../../data/flickr-dataset/captions.txt")

# %%
import torch
import math
dataset_len = len(dataset)

train, val, test = torch.utils.data.random_split(dataset, lengths = [math.floor(dataset_len*0.8), math.ceil(dataset_len*0.1), math.floor(dataset_len*0.1)])

# %%
train_loader = DataLoader(dataset, batch_size = 4, shuffle=True)    
img, label = next(iter(train_loader))

# %%
img
# Out:
# tensor([[[[0.6353, 0.6357, 0.6302,  ..., 0.1365, 0.1231, 0.1582],
#           [0.5760, 0.5967, 0.5744,  ..., 0.1337, 0.1339, 0.1024],
#           [0.5520, 0.5816, 0.5575,  ..., 0.1570, 0.1479, 0.1607],
#           ...,
#           [0.4825, 0.5057, 0.4835,  ..., 0.6474, 0.6597, 0.6401],
#           [0.4810, 0.4955, 0.4755,  ..., 0.6194, 0.6410, 0.6527],
#           [0.4960, 0.4735, 0.4464,  ..., 0.6061, 0.6316, 0.6367]],
#
#          [[0.5069, 0.5003, 0.5072,  ..., 0.0894, 0.0723, 0.1171],
#           [0.4572, 0.4841, 0.4723,  ..., 0.0936, 0.0957, 0.0741],
#           [0.4347, 0.4717, 0.4554,  ..., 0.1180, 0.1152, 0.1331],
#           ...,
#           [0.3741, 0.3904, 0.3671,  ..., 0.5101, 0.5224, 0.4905],
#           [0.3634, 0.3779, 0.3649,  ..., 0.4843, 0.5037, 0.5076],
#           [0.3901, 0.3666, 0.3423,  ..., 0.4777, 0.4943, 0.4916]],
#
#          [[0.4186, 0.3993, 0.4136,  ..., 0.0894, 0.0765, 0.1132],
#           [0.4175, 0.4330, 0.4189,  ..., 0.0898, 0.0878, 0.0614],
# ...

# %%
idx = 0

plt.imshow(img[idx].squeeze(0).permute(1,2,0))
plt.show()
print (label[idx])
# Out:
# A boy jumps into a pool while a girl watches .
